# %%
print("1111")
# Out:
# 1111

# %%
pip install faird
# Out:
# ...
#   Using cached faird-1.0.2-py3-none-any.whl.metadata (572 bytes)
# ...
#   Using cached pyarrow-19.0.0.tar.gz (1.1 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached netcdf4-1.7.2-cp312-cp312-macosx_10_15_x86_64.whl
# ...
#   Using cached rasterio-1.4.3-cp312-cp312-macosx_10_15_x86_64.whl.metadata (9.1 kB)
# ...
#   Using cached cftime-1.6.4.post1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (8.7 kB)
# ...
#   Using cached affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# ...
# Using cached faird-1.0.2-py3-none-any.whl (20 kB)
# Using cached rasterio-1.4.3-cp312-cp312-macosx_10_15_x86_64.whl (21.5 MB)
# Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# ...
